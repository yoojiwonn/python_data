# %%
import pandas as pd

# %%
df = pd.read_csv('mpg.csv')

# %%
df
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
df_1=df.groupby('model').agg(mean_hwy=('hwy','mean'))

# %%
df.groupby('model').agg(mean_hwy=('hwy','mean'))
# Out:
#                          mean_hwy
# model
# 4runner 4wd             18.833333
# a4                      28.285714
# a4 quattro              25.750000
# a6 quattro              24.000000
# altima                  28.666667
# c1500 suburban 2wd      17.800000
# camry                   28.285714
# camry solara            28.142857
# caravan 2wd             22.363636
# civic                   32.555556
# corolla                 34.000000
# corvette                24.800000
# dakota pickup 4wd       17.000000
# durango 4wd             16.000000
# expedition 2wd          17.333333
# explorer 4wd            18.000000
# f150 pickup 4wd         16.428571
# forester awd            25.000000
# grand cherokee 4wd      17.625000
# grand prix              26.400000
# gti                     27.400000
# impreza awd             26.000000
# jetta                   29.111111
# k1500 tahoe 4wd         16.250000
# land cruiser wagon 4wd  16.500000
# malibu                  27.600000
# ...

# %%
df.groupby('model').mean()
# Out:
#                            displ         year       cyl        cty        hwy
# model
# 4runner 4wd             3.483333  2002.000000  5.666667  15.166667  18.833333
# a4                      2.328571  2002.857143  4.857143  18.857143  28.285714
# a4 quattro              2.425000  2003.500000  5.000000  17.125000  25.750000
# a6 quattro              3.366667  2005.000000  6.666667  16.000000  24.000000
# altima                  2.800000  2005.000000  4.666667  20.666667  28.666667
# c1500 suburban 2wd      5.520000  2006.200000  8.000000  12.800000  17.800000
# camry                   2.671429  2002.857143  4.857143  19.857143  28.285714
# camry solara            2.642857  2002.857143  4.857143  19.857143  28.142857
# caravan 2wd             3.390909  2003.090909  5.818182  15.818182  22.363636
# civic                   1.711111  2003.000000  4.000000  24.444444  32.555556
# corolla                 1.800000  2002.600000  4.000000  25.600000  34.000000
# ...

# %%
import numpy as np

# %%
df_2= df.head(10)

# %%
df_2
# Out:
#   manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0         audi          a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1         audi          a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2         audi          a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3         audi          a4    2.0  2008    4    auto(av)   f   21   30  p
# 4         audi          a4    2.8  1999    6    auto(l5)   f   16   26  p
# 5         audi          a4    2.8  1999    6  manual(m5)   f   18   26  p
# 6         audi          a4    3.1  2008    6    auto(av)   f   18   27  p
# 7         audi  a4 quattro    1.8  1999    4  manual(m5)   4   18   26  p
# 8         audi  a4 quattro    1.8  1999    4    auto(l5)   4   16   25  p
# 9         audi  a4 quattro    2.0  2008    4  manual(m6)   4   20   28  p
#
#   category
# 0  compact
# 1  compact
# 2  compact
# 3  compact
# 4  compact
# 5  compact
# 6  compact
# 7  compact
# 8  compact
# 9  compact

# %%
df_2['hwy'].mean()
# Out:
# 27.7

# %%
df_2.loc[[1,5,9],['hwy']] = np.nan

# %%
df_2.isna().sum()
# Out:
# manufacturer    0
# model           0
# displ           0
# year            0
# cyl             0
# trans           0
# drv             0
# cty             0
# hwy             3
# fl              0
# category        0
# dtype: int64

# %%
df_2['hwy'].mean()
# Out:
# 27.714285714285715

# %%
df_2['hwy'] = df_2['hwy'].fillna(27)
# Out:
# C:\Users\julia\AppData\Local\Temp\ipykernel_24976\3233778614.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['hwy'] = df_2['hwy'].fillna(27)

# %%
df_2['hwy'].mean()
# Out:
# 27.5
